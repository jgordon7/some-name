# %% [markdown]
# ##My Awesome Analysis

# %% [markdown]
# This notebook uses the following libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Import data downloaded from github.com/swcarpentry

# %%
gap_data = pd.read_csv("data/gapminder-FiveYearData.csv", header=0)

# %% [markdown]
# (Check)

# %%
print gap_data[0:6]
# Out:
#        country  year       pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372      Asia   38.438  786.113360

# %% [markdown]
# Extract information

# %%
def pop_year(df, year):
    pop_data = df[(df.year==1952)][["continent","pop"]].groupby("continent").sum().sort("pop")
    return pop_data

print pop_year(gap_data,1952)
# Out:
#                     pop
# continent
# Oceania    1.068601e+07
# Africa     2.376405e+08
# Americas   3.451524e+08
# Europe     4.181208e+08
# Asia       1.395357e+09

# %% [markdown]
# Plot my data

# %%
def pop_plot(df,year):
    '''Function that calculates total population per continent for a year. Input: dataframe,year,Output: resulting dataframe'''
    assert type(year) is int, "Argument is not a number"
    assert year>1950, "Year to small"
    types = list(df.index)
    y_pos = np.arange(len(types))

    plt.barh(y_pos, df["pop"] , align='center')
    plt.yticks(y_pos, types)
    plt.xlabel('sum of pop')
    plt.ylabel('continent')
    plt.show()
    year_string =str(year)
    plt.title(' sum of population in'+ year_string)

# %%
print gap_data.year.describe()

years = range(1952, 2012,5)
print years
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64
# [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]

# %%
for year in years:
    pop_plot(pop_year(gap_data,year),year)
